# %%
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next

class Solution:
    def mergeTwoLists(self, list1: Optional[ListNode], list2: Optional[ListNode]) -> Optional[ListNode]:        
        dummy = ListNode()
        # Find out the length of list1
        curr = list1
        len_of_lst1_node = 0
        while curr:
            len_of_lst1_node += 1
            curr = curr.next
        
        # Find out the length of list2
        curr = list2
        len_of_lst2_node = 0
        while curr:
            len_of_lst2_node += 1
            curr = curr.next

        dummy = ListNode()
        d = dummy

        # Handle Exceptional Cases
        if (len_of_lst1_node ==0) and (len_of_lst2_node == 0):
            return dummy.next
        elif len_of_lst1_node ==0:
            return list2
        elif len_of_lst2_node == 0:
            return list1
        
    
        curr1, curr2 = list1, list2
        i, j = 0,0
        while i < len_of_lst1_node and j < len_of_lst2_node:
            print(i, j)
            if curr1.val <= curr2.val:
                d.next = curr1
                curr1 = curr1.next
                i  = i+1
            else:
                d.next = curr2
                curr2 = curr2.next
                j  = j+1
            
            d = d.next

        if i < len_of_lst1_node:
            d.next = curr1
            curr1 = curr1.next
            i += 1
        elif j < len_of_lst2_node:
            d.next = curr2
            curr2 = curr2.next
            j+=1
        


        return dummy.next

# %% [markdown]
# #### Better Solution - low Runtime

# %%
class Solution:
    def mergeTwoLists(self, list1: Optional[ListNode], list2: Optional[ListNode]) -> Optional[ListNode]:
        if list1 is None:
            return list2
        elif list2 is None:
            return list1
        elif list1.val < list2.val:
            list1.next = self.mergeTwoLists(list1.next, list2)
            return list1
        else:
            list2.next = self.mergeTwoLists(list1, list2.next)
            return list2
