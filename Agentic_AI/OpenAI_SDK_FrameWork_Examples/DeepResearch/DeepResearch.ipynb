# %%
# Basic Packages
import os
import asyncio
from dotenv import load_dotenv
from pydantic import BaseModel

# openAI SDK packages
from agents import Agent, Tool, Handoff, trace, Runner, function_tool, OpenAIChatCompletionsModel
from openai import AsyncOpenAI

# Some formatting packages

# %%
# Load Env Variables
load_dotenv(override=True)
# Out:
# True
